# %% [markdown]
# <a href="https://colab.research.google.com/github/itripathi423-a11y/Assignment1-AI/blob/main/5CS037_Assignment1_IshanTripathi_2462302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.1 Problem - 1A - Single Year HDI Exploration (Latest Year: 2022)
# Objective:
# Explore the HDI dataset for the latest available year (2022) to practice basic EDA techniques.
# Tasks:
# Complete all the Following Tasks:
# 1. Extract Latest Year:
# • Identify unique years in the dataset.
# • Filter the dataset to include only observations from the year 2022.
# • Save the filtered dataframe as hdi 2022 df (used for all subsequent tasks in Problem 1A).
# 2. Data Exploration:
# • Display the first 10 rows of the 2022 dataset.
# • Count the number of rows and columns.
# • List all column names and their data types.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
dataset=pd.read_csv('/content/Human_Development_Index_Dataset.csv',encoding='latin1')
datasetdf=pd.DataFrame(dataset)
#• Identify unique years in the dataset.
unique_years = datasetdf['year'].unique()
print("Unique years in the dataset:", unique_years)

#• Filter the dataset to include only observations from the year 2022.
hdi_2022_df = datasetdf[datasetdf['year'] == 2022]

#• Display the first 10 rows of the 2022 dataset.
print(hdi_2022_df.head(10))

#• Count the number of rows and columns.
print("\nNumber of rows and columns:", hdi_2022_df.shape)

#• List all column names and their data types.
print("\nColumn names and data types:")
print(hdi_2022_df.dtypes)

#• Check for missing values in each column and report total counts.
missing_values = hdi_2022_df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)
print("Number of missing values=",missing_values.sum())
# Out:
# Unique years in the dataset: [1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021 2022]
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# 65       2.842321  0.780277  0.798432        79.472  ...               0.977
# 98      44.903225  0.681844  0.773800        78.457  ...               0.881
# 131      0.079824       NaN       NaN        85.838  ...                 NaN
# 164     35.588987  0.560890  0.619680        64.541  ...               0.905
# 197      0.093763       NaN       NaN        81.645  ...                 NaN
# 230     45.510318  0.841405  0.845473        79.277  ...               0.995
# 263      2.780469  0.795110  0.774942        78.447  ...               1.026
# 296     26.177414  0.934602  0.955941        85.453  ...               0.978
# 329      8.939617  0.911592  0.937756        84.600  ...               0.972
#
#      gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 32               0.665                 7.042050                24.077040
# 65               0.116                82.249185                86.476634
# 98               0.460                42.910456                46.815170
# 131                NaN                81.718277                84.599998
# 164              0.520                21.339865                37.411946
# 197                NaN                      NaN                      NaN
# 230              0.292                73.591541                71.648085
# 263              0.198                96.001381                97.050957
# 296              0.063                94.580063                94.430069
# 329              0.048               100.000000               100.000000
#
#      seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 32                 27.215190                72.784810
# 65                 35.714286                64.285714
# 98                  7.005254                92.994746
# 131                46.428571                53.571429
# 164                33.636364                66.363636
# 197                31.428571                68.571429
# 230                44.376900                55.623100
# 263                35.514019                64.485981
# 296                44.493392                55.506608
# 329                40.983607                59.016393
#
#      labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 32                      23.33                     77.09           0.306318
# 65                      56.08                     69.91           1.717758
# 98                      17.57                     65.53           4.079540
# 131                       NaN                       NaN           4.593593
# 164                     74.73                     78.16           0.507359
# 197                       NaN                       NaN           6.401056
# 230                     52.08                     71.74           4.190779
# 263                     62.80                     71.84           2.531088
# 296                     62.31                     71.13          14.914763
# 329                     56.55                     66.69           7.399461
#
#      mat_footprint_percap_tons
# 32                      1.1809
# 65                     11.7367
# 98                      8.7199
# 131                        NaN
# 164                     3.6568
# 197                        NaN
# 230                    14.4512
# 263                     7.3553
# 296                    26.9245
# 329                    27.9621
#
# [10 rows x 30 columns]
#
# Number of rows and columns: (206, 30)
#
# Column names and data types:
# Unnamed: 0                     int64
# iso3                          object
# country                       object
# year                           int64
# hdi                          float64
# life_expectancy              float64
# pop_millions                 float64
# hdi_f                        float64
# hdi_m                        float64
# life_expec_f                 float64
# life_expec_m                 float64
# expec_yr_school              float64
# expec_yr_school_f            float64
# expec_yr_school_m            float64
# mean_yr_school               float64
# mean_yr_school_f             float64
# mean_yr_school_m             float64
# gross_inc_percap             float64
# gross_inc_percap_f           float64
# gross_inc_percap_m           float64
# gender_development           float64
# gender_inequality            float64
# secondary_education_f_%      float64
# secondary_education_m_%      float64
# seats_in_parliament_f_%      float64
# seats_in_parliament_m_%      float64
# labour_participation_f_%     float64
# labour_participation_m_%     float64
# co2_emission_tons            float64
# mat_footprint_percap_tons    float64
# dtype: object
#
# Missing values in each column:
# Unnamed: 0                    0
# iso3                          0
# country                       0
# year                          0
# hdi                           2
# life_expectancy               0
# pop_millions                  0
# hdi_f                        13
# hdi_m                        13
# life_expec_f                  0
# life_expec_m                  0
# expec_yr_school               1
# expec_yr_school_f             1
# expec_yr_school_m             1
# mean_yr_school                2
# mean_yr_school_f              2
# mean_yr_school_m              2
# gross_inc_percap              2
# gross_inc_percap_f           13
# gross_inc_percap_m           13
# gender_development           13
# gender_inequality            29
# secondary_education_f_%      17
# secondary_education_m_%      17
# seats_in_parliament_f_%       2
# seats_in_parliament_m_%       2
# labour_participation_f_%     12
# labour_participation_m_%     12
# co2_emission_tons             2
# mat_footprint_percap_tons    41
# dtype: int64
# Number of missing values= 212

# %% [markdown]
# 3. Missing Values & Data Cleaning:
# • Check for missing values in each column and report total counts.
# • Inspect dataset for:
# – numeric columns stored as text,
# – inconsistent or misspelled country names,
# – duplicate rows,
# – special characters (e.g., “–”) representing missing data.

# %%
obj_cols = hdi_2022_df.select_dtypes(include='object').columns
print("Columns with object type:", obj_cols)

#– inconsistent or misspelled country names,
hdi_2022_df.loc[:, 'country'] = (hdi_2022_df['country'].astype(str).str.strip().str.title())

print(hdi_2022_df.duplicated().sum())

for col in hdi_2022_df:
    count = hdi_2022_df[col].isna().sum()
    print(f"{col}: {count}")

hdi_2022_df = hdi_2022_df.dropna()
for col in hdi_2022_df:
    count = hdi_2022_df[col].isna().sum()
    print(f"{col}: {count}")
# Out:
# Columns with object type: Index(['iso3', 'country'], dtype='object')
# 0
# Unnamed: 0: 0
# iso3: 0
# country: 0
# year: 0
# hdi: 2
# life_expectancy: 0
# pop_millions: 0
# hdi_f: 13
# hdi_m: 13
# life_expec_f: 0
# life_expec_m: 0
# expec_yr_school: 1
# expec_yr_school_f: 1
# expec_yr_school_m: 1
# mean_yr_school: 2
# mean_yr_school_f: 2
# mean_yr_school_m: 2
# gross_inc_percap: 2
# gross_inc_percap_f: 13
# gross_inc_percap_m: 13
# gender_development: 13
# gender_inequality: 29
# secondary_education_f_%: 17
# secondary_education_m_%: 17
# seats_in_parliament_f_%: 2
# seats_in_parliament_m_%: 2
# labour_participation_f_%: 12
# labour_participation_m_%: 12
# co2_emission_tons: 2
# mat_footprint_percap_tons: 41
# Unnamed: 0: 0
# iso3: 0
# country: 0
# year: 0
# hdi: 0
# life_expectancy: 0
# pop_millions: 0
# hdi_f: 0
# hdi_m: 0
# life_expec_f: 0
# life_expec_m: 0
# expec_yr_school: 0
# expec_yr_school_f: 0
# expec_yr_school_m: 0
# mean_yr_school: 0
# mean_yr_school_f: 0
# mean_yr_school_m: 0
# gross_inc_percap: 0
# gross_inc_percap_f: 0
# gross_inc_percap_m: 0
# gender_development: 0
# gender_inequality: 0
# secondary_education_f_%: 0
# secondary_education_m_%: 0
# seats_in_parliament_f_%: 0
# seats_in_parliament_m_%: 0
# labour_participation_f_%: 0
# labour_participation_m_%: 0
# co2_emission_tons: 0
# mat_footprint_percap_tons: 0

# %% [markdown]
# • Apply necessary cleaning steps:
# – convert data types where needed,
# – remove duplicates,
# – handle missing values (drop or impute; justify your choice).

# %%
hdi_2022_df = hdi_2022_df.dropna(subset=['hdi'])

# %% [markdown]
# 4. Basic Statistics:
# • Compute the mean, median, and standard deviation of HDI for the year 2022.
# • Identify the country with the highest HDI in 2022.
# • Identify the country with the lowest HDI in 2022.

# %%
#Mean
mean_hdi=hdi_2022_df['hdi'].mean()
print("Mean HDI:", mean_hdi)

#Median
median_hdi=hdi_2022_df['hdi'].median()
print("Median HDI:", median_hdi)

#standard Deviation
std_hdi=hdi_2022_df['hdi'].std()
print("Standard Deviation HDI:", std_hdi)

#Highest
highest_hdi_country = hdi_2022_df.loc[hdi_2022_df['hdi'].idxmax(), ['country', 'hdi']]
print(highest_hdi_country)

#Lowest
lowest_hdi_country = hdi_2022_df.loc[hdi_2022_df['hdi'].idxmin(), ['country', 'hdi']]
print(lowest_hdi_country)
# Out:
# Mean HDI: 0.7314177215189873
# Median HDI: 0.759
# Standard Deviation HDI: 0.1571854442617671
# country    Switzerland
# hdi              0.967
# Name: 5609, dtype: object
# country    Somalia
# hdi           0.38
# Name: 5345, dtype: object

# %% [markdown]
# 5. Filtering and Sorting:
#
# • Filter countries with HDI {"hdi"} greater than 0.800.
#
# • Sort this filtered dataset by Gross National Income (GNI) per Capita {"gross inc percap"} in descending order.
#
# • Display the top 10 countries.

# %%
# • Filter countries with HDI {"hdi"} greater than 0.800.
high_hdi_df = hdi_2022_df.loc[hdi_2022_df['hdi'] > 0.800]

#Sort this filtered dataset by Gross National Income (GNI) per Capita {"gross inc percap"} in descending order.
high_hdi_sorted = high_hdi_df.sort_values(by='gross_inc_percap',ascending=False)

#Display the top 10 countries.
high_hdi_sorted[['country', 'hdi', 'gross_inc_percap']].head(10)
# Out:
#                    country    hdi  gross_inc_percap
# 4718                 Qatar  0.875       95944.37754
# 5213             Singapore  0.949       88761.14559
# 2705               Ireland  0.950       87467.51391
# 3398            Luxembourg  0.927       78554.23640
# 6104  United Arab Emirates  0.937       74103.71494
# 5609           Switzerland  0.967       69432.78669
# 4322                Norway  0.966       69189.76165
# 6170         United States  0.927       65564.93798
# 1550               Denmark  0.952       62018.95694
# 824      Brunei Darussalam  0.823       59245.63485

# %% [markdown]
# 6. Adding HDI Category Column:
# • Create a new column HDI Category that classifies each country into one of the four official
# Human Development Index groups. The classification should be based on the HDI value for the
# year 2022. Use the following categories and thresholds defined by the United Nations Development
# Programme (UNDP):
#
# HDI Category HDI Range (hdi)
# Low < 0.550
# Medium 0.550 – 0.699
# High 0.700 – 0.799
# Very ≥ 0.800

# %%
import numpy as np

conditions = [
    hdi_2022_df['hdi'] < 0.550,
    (hdi_2022_df['hdi'] >= 0.550) & (hdi_2022_df['hdi'] <= 0.699),
    (hdi_2022_df['hdi'] >= 0.700) & (hdi_2022_df['hdi'] <= 0.799),
    hdi_2022_df['hdi'] >= 0.800
]

categories = ['Low', 'Medium', 'High', 'Very High']

hdi_2022_df.loc[:, 'HDI Category'] = np.select(conditions,categories,default=None)
hdi_2022_df['HDI Category'].value_counts()
# Out:
# HDI Category
# Very High    60
# High         40
# Medium       30
# Low          28
# Name: count, dtype: int64

# %% [markdown]
# 3.2 Problem - 1B - HDI Visualization and Trend Analysis (2020 – 2022)
# Objective:
# Analyze multi-year HDI patterns (2020, 2021, and 2022) to explore temporal changes, regional differences,
# and trends across countries.
# Tasks:
# Complete all the Following Tasks:
# 1. Data Extraction and Saving:
# • Filter the dataset to include only the years 2020, 2021, and 2022.
# • Save the filtered dataset as HDI problem1B.csv.
# • Use this cleaned dataset for all subsequent tasks in Problem 1B.

# %%
#• Filter the dataset to include only the years 2020, 2021, and 2022.
hdi_filtered = datasetdf[datasetdf['year'].isin([2020, 2021, 2022])]

#• Save the filtered dataset as HDI problem1B.csv.
hdi_filtered.to_csv('HDI_problem1B.csv', index=False)

# %% [markdown]
# #2. Data Cleaning:
# • Check for missing values in the following essential columns:
# – hdi
# – country
# – year

# %%
hdi_filtered[['hdi', 'country', 'year']].isnull().sum()
# Out:
# hdi        8
# country    0
# year       0
# dtype: int64

# %% [markdown]
# • Identify and address the following issues:
# – missing or null values,
# – inconsistent or misspelled country names,
# – duplicate rows,
# – numeric columns stored as text or containing non-numeric symbols (e.g., “–”).

# %%
#– inconsistent or misspelled country names,
hdi_filtered.loc[:, 'country'] = (hdi_filtered['country'].astype(str).str.strip().str.title())

#– duplicate rows,
hdi_filtered.duplicated().sum()

#– numeric columns stored as text or containing non-numeric symbols (e.g., “–”).
hdi_filtered.dtypes
# Out:
# Unnamed: 0                     int64
# iso3                          object
# country                       object
# year                           int64
# hdi                          float64
# life_expectancy              float64
# pop_millions                 float64
# hdi_f                        float64
# hdi_m                        float64
# life_expec_f                 float64
# life_expec_m                 float64
# expec_yr_school              float64
# expec_yr_school_f            float64
# expec_yr_school_m            float64
# mean_yr_school               float64
# mean_yr_school_f             float64
# mean_yr_school_m             float64
# gross_inc_percap             float64
# gross_inc_percap_f           float64
# gross_inc_percap_m           float64
# gender_development           float64
# gender_inequality            float64
# secondary_education_f_%      float64
# secondary_education_m_%      float64
# seats_in_parliament_f_%      float64
# seats_in_parliament_m_%      float64
# labour_participation_f_%     float64
# labour_participation_m_%     float64
# co2_emission_tons            float64
# mat_footprint_percap_tons    float64
# dtype: object

# %% [markdown]
# • Apply and justify cleaning steps, including:
# – handling missing values (dropping or imputing),
# – converting data types appropriately,
# – removing duplicate entries,
# – ensuring consistent naming conventions for countries and years.
# • All cleaning decisions must be clearly justified in the final report.

# %%
# Drop rows with missing HDI, year, or GNI per capita
hdi_filtered = hdi_filtered.dropna(subset=['hdi', 'year', 'gross_inc_percap'])

#– converting data types appropriately,
numeric_columns = [
    'hdi',
    'life_expectancy',
    'gross_inc_percap']

for col in numeric_columns:
    hdi_filtered[col] = pd.to_numeric(hdi_filtered[col], errors='coerce')

#– ensuring consistent naming conventions for countries and years.
hdi_filtered['country'] = hdi_filtered['country'].str.strip()

# %% [markdown]
# 3. Visualization Tasks:
#
# • A. Line Chart — HDI Trend (Country-Level):
#
# – Select any five countries (or five countries from a region of your choice).
#
# – Plot HDI values for each country across the years 2020, 2021, and 2022.
#
# – Ensure the chart includes appropriate axis labels, a legend, and an informative caption.

# %%
import matplotlib.pyplot as plt

selected_countries = ['Nepal', 'India', 'China', 'USA', 'Japan']

df_plot = hdi_filtered[hdi_filtered['country'].isin(selected_countries)]
df_plot = df_plot.sort_values(by=['country', 'year'])
plt.figure()

for country in selected_countries:
    country_data = df_plot[df_plot['country'] == country]
    plt.plot(
        country_data['year'],
        country_data['hdi'],
        marker='o',
        label=country
    )

plt.xlabel('Year')
plt.ylabel('Human Development Index (HDI)')
plt.title('HDI Trends for Selected Countries (2020–2022)')
plt.legend()

plt.show()

# %% [markdown]
# B.Generate Visualization:
#
# Bar Chart:
#
# -Average HDI by region

# %%
hdi_filtered.columns
# Out:
# Index(['Unnamed: 0', 'iso3', 'country', 'year', 'hdi', 'life_expectancy',
#        'pop_millions', 'hdi_f', 'hdi_m', 'life_expec_f', 'life_expec_m',
#        'expec_yr_school', 'expec_yr_school_f', 'expec_yr_school_m',
#        'mean_yr_school', 'mean_yr_school_f', 'mean_yr_school_m',
#        'gross_inc_percap', 'gross_inc_percap_f', 'gross_inc_percap_m',
#        'gender_development', 'gender_inequality', 'secondary_education_f_%',
#        'secondary_education_m_%', 'seats_in_parliament_f_%',
#        'seats_in_parliament_m_%', 'labour_participation_f_%',
#        'labour_participation_m_%', 'co2_emission_tons',
#        'mat_footprint_percap_tons'],
#       dtype='object')

# %%
# region_avg =hdi_filtered.groupby(['region'])['hdi'].mean().reset_index()
# plt.figure()
# sns.barplot(data=region_avg, x='region', y='hdi')
# plt.xlabel('Region')
# plt.ylabel('Average HDI')
# plt.title('Average HDI by Region')
# plt.show()

# %% [markdown]
# The dataset donot contain region so cannot create the bar plot.

# %% [markdown]
# – Box Plot: HDI Distribution for 2020, 2021, and 2022
# ∗ Filter the dataset for the years 2020, 2021, and 2022.
# ∗ Create a box plot showing HDI spread for each of the three years.
# ∗ Include titles and axis labels.
# ∗ Comment briefly on distribution differences.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_box = hdi_filtered[hdi_filtered['year'].isin([2020, 2021, 2022])]
plt.figure(figsize=(8,6))
sns.boxplot(x='year', y='hdi', data=df_box)

plt.xlabel('Year')
plt.ylabel('Human Development Index (HDI)')
plt.title('HDI Distribution Across 2020–2022')
plt.show()

# %% [markdown]
# – Scatter Plot: HDI vs. GNI per Capita
# ∗ Check if the dataset contains a column for GNI per Capita.
# ∗ If available:
# · Create a scatter plot using HDI as the dependent variable.
# · Use GNI per Capita on the x-axis.
# · Add a regression line (optional).
# ∗ If the variable is missing, write:
# "GNI per Capita variable not available in the dataset."

# %%
if 'gross_inc_percap' in hdi_filtered.columns:

    plt.figure(figsize=(8,6))
    sns.scatterplot(x='gross_inc_percap', y='hdi', data=hdi_filtered)

    plt.xlabel('Gross National Income per Capita')
    plt.ylabel('Human Development Index (HDI)')
    plt.title('HDI vs. GNI per Capita (2020–2022)')
    plt.show()

else:
    print("GNI per Capita variable not available in the dataset.")

# %% [markdown]
# #Problem 2
# Advanced HDI Exploration
# Objective:
#
# Perform advanced analysis of HDI data, focusing on South Asian countries, composite metrics, outlier detec-
# tion, metric relationships, and gap analysis.
#
# Tasks:
# Complete all the following tasks:
# 1. Create South Asia Subset:
# • Define the list of South Asian countries: ["Afghanistan", "Bangladesh", "Bhutan", "India",
# "Maldives", "Nepal", "Pakistan", "Sri Lanka"].
# • Filter the HDI dataset to include only these countries.
# • Save the filtered dataset as HDI SouthAsia.csv and include this file in the final submission.

# %%
south_asia_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]
hdi_south_asia = hdi_filtered[hdi_filtered['country'].isin(south_asia_countries)]
hdi_south_asia.to_csv('HDI_SouthAsia.csv', index=False)

# %% [markdown]
# 2. Composite Development Score:
# • Create a new metric called Composite Score using the formula:
#
# Composite Score = 0.30 × Life Expectancy Index + 0.30 × GNI per Capita Index}
# Here: Life Expectancy Index → "life expectancy" and GNI per Capita Index → "gross inc percap"
# • Rank South Asian countries based on Composite Score.

# %%
hdi_south_asia = hdi_south_asia.copy()

hdi_south_asia['Composite Score'] = (
    0.30 * hdi_south_asia['life_expectancy'] +
    0.30 * hdi_south_asia['gross_inc_percap']
)

# Compute mean Composite Score per country across years
composite_ranking = (
    hdi_south_asia.groupby('country')['Composite Score']
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

composite_ranking['Rank'] = range(1, len(composite_ranking)+1)
composite_ranking
# Out:
#        country  Composite Score  Rank
# 0     Maldives      4827.657597     1
# 1    Sri Lanka      3767.752918     2
# 2       Bhutan      3097.787317     3
# 3        India      1978.776712     4
# 4   Bangladesh      1877.251264     5
# 5     Pakistan      1565.030032     6
# 6        Nepal      1191.338108     7
# 7  Afghanistan       504.358088     8

# %% [markdown]
# • Plot the top 5 countries in a horizontal bar chart.

# %%
import matplotlib.pyplot as plt

top5 = composite_ranking.head(5)

plt.figure(figsize=(8,5))
plt.barh(top5['country'], top5['Composite Score'], color='skyblue')
plt.xlabel('Composite Score')
plt.title('Top 5 South Asian Countries by Composite Development Score')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# :• Compare the ranking of countries by Composite Score with their HDI ranking and discuss any
# differences.

# %%
hdi_ranking = (
    hdi_south_asia.groupby('country')['hdi']
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

hdi_ranking['HDI Rank'] = range(1, len(hdi_ranking)+1)

comparison = composite_ranking.merge(hdi_ranking, on='country')
comparison[['country', 'Composite Score', 'Rank', 'hdi', 'HDI Rank']]
# Out:
#        country  Composite Score  Rank       hdi  HDI Rank
# 0     Maldives      4827.657597     1  0.750667         2
# 1    Sri Lanka      3767.752918     2  0.780000         1
# 2       Bhutan      3097.787317     3  0.677667         3
# 3        India      1978.776712     4  0.638333         5
# 4   Bangladesh      1877.251264     5  0.663000         4
# 5     Pakistan      1565.030032     6  0.537667         7
# 6        Nepal      1191.338108     7  0.595000         6
# 7  Afghanistan       504.358088     8  0.474333         8

# %% [markdown]
# 3. Outlier Detection:
# • Detect outliers in HDI and GNI per Capita using the 1.5 × IQR rule.
# • Create a scatter plot of GNI per Capita vs HDI, highlighting the outliers in a different color.
# • Discuss why the identified countries stand out as outliers.

# %%
#• Detect outliers in HDI and GNI per Capita using the 1.5 × IQR rule.
print("\nHDI OUTLIER")
Q1_hdi=hdi_south_asia['hdi'].quantile(0.25)
Q3_hdi=hdi_south_asia['hdi'].quantile(0.75)
IQR_hdi=Q3_hdi-Q1_hdi
lower_outlier_hdi=Q1_hdi-1.5*IQR_hdi
upper_outlier_hdi=Q3_hdi+1.5*IQR_hdi
hdi_outliers = hdi_south_asia[(hdi_south_asia['hdi'] < lower_outlier_hdi) |(hdi_south_asia['hdi'] > upper_outlier_hdi)]
print(hdi_outliers[['country', 'hdi']])
#GNI
print("\nGNI OUTLIER")
Q1_GNI=hdi_south_asia['gross_inc_percap'].quantile(0.25)
Q3_GNI=hdi_south_asia['gross_inc_percap'].quantile(0.75)
IQR_GNI=Q3_GNI-Q1_GNI
lower_outlier_GNI=Q1_GNI-1.5*IQR_GNI
upper_outlier_GNI=Q3_GNI+1.5*IQR_GNI
GNI_outliers = hdi_south_asia[(hdi_south_asia['gross_inc_percap'] < lower_outlier_GNI) |(hdi_south_asia['gross_inc_percap'] > upper_outlier_GNI)]
print(GNI_outliers[['country', 'gross_inc_percap']])

#• Create a scatter plot of GNI per Capita vs HDI, highlighting the outliers in a different color.
plt.scatter(hdi_south_asia["gross_inc_percap"], hdi_south_asia["hdi"], label="Normal")
plt.scatter(GNI_outliers["gross_inc_percap"],GNI_outliers["hdi"], color="red", label="Outliers")
plt.legend()
plt.title("GNI per Capita Vs HDI")
plt.xlabel("GNI per Capita")
plt.ylabel("HDI")
plt.show()
# Out:
# HDI OUTLIER
# Empty DataFrame
# Columns: [country, hdi]
# Index: []
#
# GNI OUTLIER
# Empty DataFrame
# Columns: [country, gross_inc_percap]
# Index: []

# %% [markdown]
# 4. Exploring Metric Relationships:
# • Select two HDI components (e.g., Gender Development Index {"gender development"} and Life
# Expectancy Index {"life expectancy"}).
# • Compute Pearson correlation of each metric with HDI.
# • Create scatter plots with trendlines to visualize the relationships.

# %%
# Pearson correlation between HDI and Life Expectancy Index
corr_life = hdi_filtered['hdi'].corr(hdi_filtered['life_expectancy'])
print(f"Pearson correlation between HDI and Life Expectancy Index: {corr_life:.3f}")

# Pearson correlation between HDI and Gender Development Index
corr_gender = hdi_filtered['hdi'].corr(hdi_filtered['gender_development'])
print(f"Pearson correlation between HDI and Gender Development Index: {corr_gender:.3f}")


# --- Scatter plot: HDI vs Life Expectancy Index ---
plt.figure(figsize=(6,5))
sns.scatterplot(x=hdi_filtered['life_expectancy'], y=hdi_filtered['hdi'])
plt.xlabel('Life Expectancy Index')
plt.ylabel('HDI')
plt.title('HDI vs Life Expectancy Index')
plt.show()


# --- Scatter plot: HDI vs Gender Development Index ---
plt.figure(figsize=(6,5))
sns.scatterplot(x=hdi_filtered['gender_development'], y=hdi_filtered['hdi'])
plt.xlabel('Gender Development Index')
plt.ylabel('HDI')
plt.title('HDI vs Gender Development Index')
plt.show()
# Out:
# Pearson correlation between HDI and Life Expectancy Index: 0.902
# Pearson correlation between HDI and Gender Development Index: 0.616

# %% [markdown]
# 5. Gap Analysis:
# • Create a new metric:
#
# GNI HDI Gap = "gross inc percap" − "hdi"
# • Rank South Asian countries by GNI HDI Gap in descending and ascending order.
# • Plot the top 3 positive gaps and top 3 negative gaps.
# • Discuss the implications of the gap, e.g., cases where GNI is high but HDI is lower than expected.

# %%
# Create a new metric: GNI HDI Gap = "gross inc percap" − "hdi"
hdi_south_asia_mean = hdi_south_asia.groupby("country")[["gross_inc_percap", "hdi"]].mean()
hdi_south_asia_mean['GNI_HDI_GAP'] = hdi_south_asia_mean['gross_inc_percap'] - hdi_south_asia_mean['hdi']
print(hdi_south_asia_mean['GNI_HDI_GAP'])

# Rank South Asian countries by GNI HDI Gap in descending order
gap_desc = hdi_south_asia_mean.sort_values(by='GNI_HDI_GAP', ascending=False).reset_index()
print("\nGap in Descending Order")
print(gap_desc[['country','GNI_HDI_GAP']])

# Rank South Asian countries by GNI HDI Gap in ascending order
gap_asc = hdi_south_asia_mean.sort_values(by='GNI_HDI_GAP', ascending=True).reset_index()
print("\nGap in Ascending Order")
print(gap_asc[['country','GNI_HDI_GAP']])

# Bar chart
top3_positive = gap_desc.head(3)
top3_negative = gap_asc.head(3)
top_gaps = pd.concat([top3_positive, top3_negative])
plt.figure(figsize=(10,6))
colors = ['skyblue']*3 + ['salmon']*3
plt.bar(top_gaps['country'], top_gaps['GNI_HDI_GAP'], color=colors)
plt.ylabel('GNI HDI Gap')
plt.xlabel('Country')
plt.title('Top 3 Positive and Negative GNI HDI Gaps in South Asia (2020–2022)')
plt.xticks(rotation=45)  # Rotate country names for readability
plt.show()
# Out:
# country
# Afghanistan     1618.240627
# Bangladesh      6184.158880
# Bhutan         10253.395723
# India           6526.906040
# Maldives       16011.230657
# Nepal           3901.138692
# Pakistan        5149.963106
# Sri Lanka      12481.929060
# Name: GNI_HDI_GAP, dtype: float64
#
# Gap in Descending Order
#        country   GNI_HDI_GAP
# 0     Maldives  16011.230657
# 1    Sri Lanka  12481.929060
# 2       Bhutan  10253.395723
# 3        India   6526.906040
# 4   Bangladesh   6184.158880
# 5     Pakistan   5149.963106
# 6        Nepal   3901.138692
# 7  Afghanistan   1618.240627
#
# Gap in Ascending Order
#        country   GNI_HDI_GAP
# 0  Afghanistan   1618.240627
# 1        Nepal   3901.138692
# 2     Pakistan   5149.963106
# 3   Bangladesh   6184.158880
# 4        India   6526.906040
# 5       Bhutan  10253.395723
# 6    Sri Lanka  12481.929060
# 7     Maldives  16011.230657

# %% [markdown]
# #Problem 3
# Comparative Regional Analysis: South Asia vs Middle East
# Objective:
# Perform a comparative analysis of HDI and related metrics between South Asia and the Middle East using
# the 2020–2022 dataset from Problem 1B.
# Tasks:
# Complete all the following tasks:
# 1. Create Middle East Subset:
# • Define the list of Middle East countries: ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
# "United Arab Emirates", "Yemen"].
# • Filter the dataset from Problem 1B (HDI problem1B.csv) to create subsets for South Asia and
# Middle East.
# • Save these subsets as HDI SouthAsia 2020 2022.csv and HDI MiddleEast 2020 2022.csv for
# use in subsequent tasks.

# %%
hdi_df = pd.read_csv('HDI_problem1B.csv')

south_asia_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
                        "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
                         "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
                         "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]

hdi_south_asia = hdi_df[hdi_df['country'].isin(south_asia_countries)].copy()
hdi_middle_east = hdi_df[hdi_df['country'].isin(middle_east_countries)].copy()

hdi_south_asia.to_csv('HDI_SouthAsia_2020_2022.csv', index=False)
hdi_middle_east.to_csv('HDI_MiddleEast_2020_2022.csv', index=False)

# %% [markdown]
# 2. Descriptive Statistics:
# • Compute the mean and standard deviation of HDI for each region (South Asia vs Middle East)
# across 2020–2022.
# • Identify which region performs better on average.

# %%
# Mean and standard deviation of HDI
sa_stats = hdi_south_asia['hdi'].agg(['mean', 'std'])
me_stats = hdi_middle_east['hdi'].agg(['mean', 'std'])

print("South Asia HDI stats:\n", sa_stats)
print("\nMiddle East HDI stats:\n", me_stats)

# Determine which region performs better on average
better_region = "South Asia" if sa_stats['mean'] > me_stats['mean'] else "Middle East"
print("\nRegion performing better on average:", better_region)
# Out:
# South Asia HDI stats:
#  mean    0.639583
# std     0.098273
# Name: hdi, dtype: float64
#
# Middle East HDI stats:
#  mean    0.788909
# std     0.141295
# Name: hdi, dtype: float64
#
# Region performing better on average: Middle East

# %% [markdown]
# 3. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on HDI.
# • Create a bar chart comparing these top and bottom performers across the two regions.

# %%
# Compute mean HDI per country across years
sa_hdi_country = hdi_south_asia.groupby('country')['hdi'].mean().sort_values(ascending=False)
me_hdi_country = hdi_middle_east.groupby('country')['hdi'].mean().sort_values(ascending=False)

# Top 3 and bottom 3 for each region
sa_top3 = sa_hdi_country.head(3)
sa_bottom3 = sa_hdi_country.tail(3)

me_top3 = me_hdi_country.head(3)
me_bottom3 = me_hdi_country.tail(3)

# Combine for plotting

fig, ax = plt.subplots(figsize=(10,6))
ax.bar(sa_top3.index, sa_top3.values, label='South Asia Top 3', color='skyblue')
ax.bar(sa_bottom3.index, sa_bottom3.values, label='South Asia Bottom 3', color='navy')
ax.bar(me_top3.index, me_top3.values, label='Middle East Top 3', color='orange')
ax.bar(me_bottom3.index, me_bottom3.values, label='Middle East Bottom 3', color='red')

plt.ylabel('HDI')
plt.title('Top and Bottom 3 HDI Countries: South Asia vs Middle East')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# \4. Metric Comparisons:
# • Compare the following metrics across regions using grouped bar charts:
# – Gender Development Index {"gender development"}
# – Life Expectancy Index {"life expectancy"}
# – GNI per Capita Index {"gross inc percap"}
# • Identify which metric shows the greatest disparity between regions.

# %%
metrics = ['gender_development', 'life_expectancy', 'gross_inc_percap']

# Compute mean per region
sa_metrics = hdi_south_asia.groupby('year')[metrics].mean().mean()  # average across years
me_metrics = hdi_middle_east.groupby('year')[metrics].mean().mean()

metric_df = pd.DataFrame({'South Asia': sa_metrics, 'Middle East': me_metrics})
metric_df.plot(kind='bar', figsize=(8,6))
plt.ylabel('Mean Value')
plt.title('Regional Comparison: HDI Metrics (2020–2022)')
plt.show()

# %% [markdown]
# 5. HDI Disparity:
# • Compute the range (max – min) of HDI for each region.
# • Compute the coefficient of variation (CV = std/mean) for HDI.
# • Identify which region exhibits more variation in HDI.

# %%
# Range (max - min) for each region
sa_range = hdi_south_asia['hdi'].max() - hdi_south_asia['hdi'].min()
me_range = hdi_middle_east['hdi'].max() - hdi_middle_east['hdi'].min()

# Coefficient of Variation (CV = std / mean)
sa_cv = hdi_south_asia['hdi'].std() / hdi_south_asia['hdi'].mean()
me_cv = hdi_middle_east['hdi'].std() / hdi_middle_east['hdi'].mean()

print(f"South Asia HDI range: {sa_range:.3f}, CV: {sa_cv:.3f}")
print(f"Middle East HDI range: {me_range:.3f}, CV: {me_cv:.3f}")
# Out:
# South Asia HDI range: 0.321, CV: 0.154
# Middle East HDI range: 0.513, CV: 0.179

# %% [markdown]
# 6. Correlation Analysis:
# • For each region, compute correlations of HDI with:
# – Gender Development Index
# – Life Expectancy Index
# • Create scatter plots with trendlines for each correlation.
# • Interpret the strength and direction of these relationships.

# %%
# HDI correlations for South Asia
print("South Asia correlations:")
print(hdi_south_asia[['hdi','gender_development','life_expectancy']].corr()['hdi'])

# HDI correlations for Middle East
print("\nMiddle East correlations:")
print(hdi_middle_east[['hdi','gender_development','life_expectancy']].corr()['hdi'])

for df, region in zip([hdi_south_asia, hdi_middle_east], ['South Asia', 'Middle East']):
    for metric in ['gender_development', 'life_expectancy']:
        plt.figure(figsize=(6,5))
        sns.scatterplot(x=df[metric], y=df['hdi'])
        plt.xlabel(metric.title())
        plt.ylabel('HDI')
        plt.title(f'{region}: HDI vs {metric.title()}')
        plt.show()
# Out:
# South Asia correlations:
# hdi                   1.000000
# gender_development    0.874218
# life_expectancy       0.938764
# Name: hdi, dtype: float64
#
# Middle East correlations:
# hdi                   1.000000
# gender_development    0.935670
# life_expectancy       0.933123
# Name: hdi, dtype: float64

# %% [markdown]
# 7. Outlier Detection:
# • Detect outliers in HDI {"hdi"} and GNI per Capita {"gross inc percap"} for each region using
# the 1.5 × IQR rule.
# • Create scatter plots highlighting outliers in a different color.
# • Discuss the significance of these outliers.

# %%
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5*IQR
    upper = Q3 + 1.5*IQR
    return df[(df[col] < lower) | (df[col] > upper)]

# HDI and GNI outliers
for region_name, df in [('South Asia', hdi_south_asia), ('Middle East', hdi_middle_east)]:
    hdi_out = detect_outliers(df, 'hdi')
    gni_out = detect_outliers(df, 'gross_inc_percap')
    print(f"{region_name} HDI Outliers:\n", hdi_out[['country','year','hdi']])
    print(f"{region_name} GNI Outliers:\n", gni_out[['country','year','gross_inc_percap']])

    # Scatter plot highlighting outliers
    plt.figure(figsize=(6,5))
    plt.scatter(df['gross_inc_percap'], df['hdi'], alpha=0.6, label='Normal')
    plt.scatter(gni_out['gross_inc_percap'], gni_out['hdi'], color='red', label='Outlier')
    plt.xlabel('GNI per Capita')
    plt.ylabel('HDI')
    plt.title(f'{region_name}: HDI vs GNI per Capita with Outliers')
    plt.legend()
    plt.show()
# Out:
# South Asia HDI Outliers:
#  Empty DataFrame
# Columns: [country, year, hdi]
# Index: []
# South Asia GNI Outliers:
#  Empty DataFrame
# Columns: [country, year, gross_inc_percap]
# Index: []
# Middle East HDI Outliers:
#      country  year    hdi
# 576   Yemen  2020  0.430
# 577   Yemen  2021  0.425
# 578   Yemen  2022  0.424
# Middle East GNI Outliers:
#  Empty DataFrame
# Columns: [country, year, gross_inc_percap]
# Index: []
